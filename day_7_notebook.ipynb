# %%
# !pip install anytree

from anytree import Node, RenderTree,NodeMixin

udo = Node("Udo")
marc = Node("Marc")
lian = Node("Lian", parent=marc)
print(RenderTree(udo))
Node('/Udo')
print(RenderTree(marc))




 
class MyBaseDirectory(object):  # Just an example of a base class
  foo = 4
class MyDirectory(MyBaseDirectory, NodeMixin):  # Add Node feature
  def __init__(self, name, length, width, parent=None, children=None):
    super(MyDirectory, self).__init__()
    self.name = name
    self.length = length
    self.width = width
    self.parent = parent
    if children:
      self.children = children

  

 
file1 = open('input_day7.txt', 'r')
lines = file1.readlines()

current_directory = "/"
my0 = MyClass('my0', 0, 0)
root = myDirectory("/")
for line in lines[0:10]:
    print(line)
    line_contents = line.split(" ")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: anytree in /usr/local/lib/python3.8/dist-packages (2.8.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from anytree) (1.15.0)
# Node('/Udo')
# Node('/Marc')
# └── Node('/Marc/Lian')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d8f121d1a6ec> in <module>
#      34 current_directory = "/"
#      35 my0 = MyClass('my0', 0, 0)
# ---> 36 root = myDirectory("/")
#      37 for line in lines[0:10]:
#      38     print(line)
#
# <ipython-input-3-a7fe182c05fb> in __init__(self, address, parent, children)
#      18
#      19   def __init__(self, address, parent=None, children=None):
# ---> 20     super(Elf_Directory, self).__init__()
#      21     self.adress = address
#      22     self.total_file_size = 0
#
# TypeError: super(type, obj): obj must be an instance or subtype of type
